# %%
class Employee:
    def __init__(self, name, salary, department):
        self.name = name
        self.salary = salary
        self.department = department
    def give_raise(self, amount):
        self.salary += amount
    def __str__(self):
        return f"{self.name} ({self.department}) {self.salary} PLN"

# %%
class Manager(Employee):
    def __init__(self, name, salary, department, team_size):
        super().__init__(name, salary, department)
        self.team_size = team_size
    def give_team_raise(self, amount):
        self.amount = amount
        self.salary = self.salary + self.amount * self.team_size
    def __str__(self):
        return f"{self.name} ({self.department} team: {self.team_size}): {self.salary} PLN"

# %%
emp = Employee("Anna", 5000, "IT")
emp.give_raise(500)
print(emp)  # "Anna (IT): 5500 PLN"

mgr = Manager("Bartek", 8000, "IT", 5)
mgr.give_team_raise(200)  # bonus = 200 * 5 = 1000, więc salary = 9000
print(mgr)  # "Bartek (IT, team: 5): 9000 PLN"
# Out:
# Anna (IT) 5500 PLN
# Bartek (IT team: 5): 9000 PLN
